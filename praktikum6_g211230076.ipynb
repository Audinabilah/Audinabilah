# %% [markdown]
# <a href="https://colab.research.google.com/github/Audinabilah/Audinabilah/blob/main/praktikum6_g211230076.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import module
import pandas as pd
import seaborn as sns
from google.colab  import files
uploaded = files.upload()

#load the csv
data1 = pd.read_csv("nba.csv")

# show first 5 columb
data1.head()
# Out:
#      <input type="file" id="files-1f3a86cf-9ed9-4d5f-b174-b0c83cb22ca8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f3a86cf-9ed9-4d5f-b174-b0c83cb22ca8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sns.lineplot(data1["Salary"])
# Out:
# <Axes: ylabel='Salary'>

# %%
sns.scatterplot(data1['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.lineplot(x=data1["Age"], y=data1["Salary"])
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.lineplot(x=data1['Age'],y=data1['Weight'], hue =data1["Position"])
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.scatterplot(x=data1['Age'],y=data1['Weight'], hue =data1["Position"])
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.boxplot (x=data1['Age'], y=data1['Weight'], palette=['#FF0000','#00FF00','#0000FF'])
# Out:
# <ipython-input-7-e790fcebcf9b>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot (x=data1['Age'], y=data1['Weight'], palette=['#FF0000','#00FF00','#0000FF'])
# <ipython-input-7-e790fcebcf9b>:1: UserWarning:
# The palette list has fewer values (3) than needed (22) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot (x=data1['Age'], y=data1['Weight'], palette=['#FF0000','#00FF00','#0000FF'])
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.pointplot(x = "Age", y = "Weight", data = data1)
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.barplot (x= "Age", y = "Weight", data = data1, palette=['#FF0000','#00FF00','#0000FF','#FF0FFF'])
# Out:
# <ipython-input-9-ad838b00441a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot (x= "Age", y = "Weight", data = data1, palette=['#FF0000','#00FF00','#0000FF','#FF0FFF'])
# <ipython-input-9-ad838b00441a>:1: UserWarning:
# The palette list has fewer values (4) than needed (22) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot (x= "Age", y = "Weight", data = data1, palette=['#FF0000','#00FF00','#0000FF','#FF0FFF'])
# <Axes: xlabel='Age', ylabel='Weight'>
